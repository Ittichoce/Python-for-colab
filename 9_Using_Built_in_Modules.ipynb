# %% [markdown]
# <a href="https://colab.research.google.com/github/Ittichoce/Python-for-colab/blob/my-branch-3/9_Using_Built_in_Modules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Using Built-in Modules**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Built-in Modules**
#
# - *Module* are Python file containing various objects and functions in closely-related programming tasks.
# - *Built-in modules* come with the Python standard library.
# - Typically, we simply make use of objects and functions from the modules.

# %% [markdown]
# ### Demonstration of using a built-in module
# Let's pick a module called `math` for this demonstration.

# %% [markdown]
# ###Letting the program know we will use a module
# To start using a module, we need to `import` the module by its name.

# %%
import math
print(math)
# Out:
# <module 'math' (built-in)>

# %% [markdown]
# ### Accessing values and  functions in the module
# Once imported, we can access values and functions in the module using the `dog operator` with the name of the module.

# %%
#let's find the value of pi 
print(math.pi)
#Find the factorial of 5 (i.e. 5! = 5 * 4 * 3 * 2 * 1 = 120)
print(math.factorial(5))
# Out:
# 3.141592653589793
# 120

# %% [markdown]
# ### Exploring how to use the module
# We can use the *built-in function* `help([module object])` to learn its documentations.

# %%
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     ceil(x, /)
#         Return the ceiling of x as an Integral.
#
#         This is the smallest integer >= x.
#
#     copysign(x, y, /)
# ...

# %% [markdown]
# from the documentation above, there are a few new notations in the function parameter that we have not yet covered.
#
#
# First is that many functions have `/` as their parameters, such as `factorial(x, /)`. This `/` is NOT an actual parameter but it is
# there just to say that **"the parameters coming before `/` are positional-only"**
#
#
# Second is that a few fuctions have `*` as thier parameters, such as `prod(iterable, /, *, start=1)` This `*` is again NOT
# an actual parameter but it says that **"the parameters coming after `*` must be input using keyword arguments.**
#
# These concepts are a bit advanced but we can now just focus on knowing how to call functions in the module.

# %% [markdown]
# ####**Example 1 Square Root Finder**
# Let's write a program to get an integer from the user and calculate the resulting square root of that integer.

# %%
# math has already been imported in this notebook 
n = input("Enter an integer n: ")
result = math.sqrt(int(n))
print("The square root of " + n + " is " + str(result) + ".")
# Out:
# Enter an integer n: 883
# The square root of 883 is 29.715315916207253.

# %% [markdown]
# ####**Example 2 Greatest Common Divisor Finder**
# The program receives 2 integers and finds the largest integer that can divide the 3 integers (with no remainders).

# %%
# math has already been imported in this notebook
n1 = int(input("Enter the 1st integer: "))
n2 = int(input("Enter the 2nd integer: "))
result = math.gcd(n1, n2)
print("The GCD is " + str(result) + ".")
# Out:
# Enter the 1st integer: 154
# Enter the 2nd integer: 28
# The GCD is 14.

# %% [markdown]
# ###**More usage variations of `import`**
#
# At this point, we should restart the Kernel (`Kernel > Restart`) to make this notebook forget all of the variables including `math`.

# %% [markdown]
# After restarting, `math` will no longer be known in this notebook.

# %% [markdown]
# ###**Renaming the module**

# %%
import math as m 
print(m.pi)
# Out:
# 3.141592653589793

# %% [markdown]
# ###**Importing specific values/functions from a modul**e

# %%
# Restart the Kernel first 
from math import sqrt, factorial as fact 
print(sqrt(144))
print(fact(5))
# Out:
# 12.0
# 120

# %%
# Restart the Kernel first 
from math import * 
print(sqrt(144))
print(factorial(5))
print(pi)
# Out:
# 12.0
# 120
# 3.141592653589793
