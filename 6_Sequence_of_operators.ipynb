# %% [markdown]
# <a href="https://colab.research.google.com/github/Ittichoce/Python-for-colab/blob/my-branch-3/6_Sequence_of_operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Sequence of operators**

# %% [markdown]
# ![02.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **Example**

# %%
2 + 3  * 5 - 6 + - 4 / 2 ** 2
# Out:
# 10.0

# %% [markdown]
# Step by step for calculation.

# %% [markdown]
# ![00.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# 1.   2 ** 2
# 2.   -4
# 3.   -4 * (2 ** 2) = -1
# 4.   3 * 5
# 5.   2 + (3 * 5)
# 6.   (2 + (3 * 5)) - 6 = 11
# 7.   11 + (-1) = 10
#
# So a answer of the example is **10**.

# %% [markdown]
# **If Precedence is equal, It start from left to right.**
#
# Except
#
# **Exponential and input value in variable (Assignment), It start from right to left.**

# %% [markdown]
# ---

# %% [markdown]
# ## Summary Sequence of operators
#  **(From High significant to low significant)**
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Examples**

# %% [markdown]
# *Example 1*
#
# 1 - 3 * (5 + 9)
#
# = 1 - 3 * 14
#
# = 1 - 42
#
# = -41

# %%
1 - 3 * (5 + 9)
# Out:
# -41

# %% [markdown]
# *Example 2*
#
# 8 % 3 ** 2 / 2
#
# 8 % 9 / 2
#
# 8       / 2
#
# 4

# %%
8 % 3 ** 2 / 2
# Out:
# 4.0

# %% [markdown]
# *Example 3*
#
# 2 ** -1 ** 4
#
# 2 ** - 1
#
# 0.5

# %%
2 ** -1 ** 4
# Out:
# 0.5

# %% [markdown]
# *Example 4*
#
# not 36 % 9  > 2    and 4 != 1
#
# not  0      > 2    and 4 != 1
#
# not  False         and 4 != 1
#
# not  False         and true
#
# True

# %%
not 36 % 9 > 2 and 4 != 1
# Out:
# True

# %% [markdown]
# *Example 5*
#
# a = b = 1 == 2
#
# a = b = False
#
# a = False  (b = False)
#
# False  (a = False, b = False)

# %%
a = b = 1 == 2 
print(a)
print(b)
# Out:
# False
# False

# %%
not not 3 < 5 == True
# Out:
# False
