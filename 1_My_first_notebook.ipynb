# %% [markdown]
# <a href="https://colab.research.google.com/github/Ittichoce/Python-for-colab/blob/main/1_My_first_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This is First time to use Jupyter notebook.
#
# This is **Markdown Cell**. We can *format* our content. Even write a list.
# - Item 1
# - Item 2

# %%
print("I will be writing python very soon!!!")
# Out:
# I will be writing python very soon!!!

# %%
a = 2
b = 3 
print(a*b)
# Out:
# 6

# %% [markdown]
# # Properties of Python

# %% [markdown]
# ![00.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![01.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![02.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![03.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![05.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # Basic Markdown syntax and format.

# %% [markdown]
# # Headline 1
# ## Headline 2
# ### Headline 3
# #### Headline 4
# ##### Headline 5
# ###### Headline 6
#
# This is a paragraph.         This is a paragraph.        This is a paragraph.            This is a paragraph.
#
# This is the second paragraph.
#
# ---
#
# This is the third paragraph.

# %% [markdown]
# we want to format **this in bold face**, while this will be on *italic*. This is very simple and smooth.

# %% [markdown]
# - Item 1
# - Item 2
# - Item 3
#
# 1. Item 1
# 1. Item 2
# 1. Item 3

# %% [markdown]
# |No.|Score|
# |---|---|
# | 1 | 99 |
# | 2 | 87 |
# | 3 | 66 |
# | 4 | 54 |

# %% [markdown]
# ---
#
# Then you want to change type of cell. After you click the cell, You hit at `m (markdown)` or `y (code)` at your keyboard.
#
# ![jupyter_shortcut.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![jupyter_shortcut2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # Example import image from link

# %% [markdown]
# ![Photo of a cute woman](https://pbs.twimg.com/media/FL6jndbXIAQsO9u?format=jpg&name=medium)

# %% [markdown]
# ![Photo of a cute woman.](https://pbs.twimg.com/media/EUn9femXQAE8546?format=jpg&name=large)

# %% [markdown]
# Under the photo, I create link my datascience course.

# %% [markdown]
# [Home page of Datarockie](https://course.datarockie.com/)
#
# ---
#
# or
#
# <https://course.datarockie.com/>

# %% [markdown]
# To start, Type `jupyter notebook` at the command prompt.

# %% [markdown]
#             function square(x){
#                 return x*x
#             }
